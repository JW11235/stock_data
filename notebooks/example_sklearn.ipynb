# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn import tree
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

# %%
wine = load_wine()

# %%
import pandas as pd

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(wine.data, wine.target, test_size=0.3)

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy', random_state=0)
clf = clf.fit(Xtrain, Ytrain)
score = clf.score(Xtest, Ytest)

# %%
score
# Out:
# 0.9444444444444444

# %%
feature_name = ['酒精','苹果酸','灰','灰的碱性','镁','总酚','类黄酮','非黄烷类酚类','花青素','颜色强度',
                '色调','od280/od315稀释葡萄酒','脯氨酸']

# %%
    
dot_data = tree.export_graphviz(clf,
                                feature_names = feature_name,
                                class_names=['琴酒', '雪莉', '贝尔摩德'],
                                filled=True,
                                rounded=True
)

# %%
import os
import graphviz

# path_g = 'C:\ProgramData\Anaconda3\Lib\site-packages\graphviz'
# # # path_g = 'C:\ProgramData\Anaconda3\Lib\site-packages\graphviz-0.17.dist-info'
# os.environ['path'] += os.pathsep + path_g
graph = graphviz.Source(dot_data)

# %%
graph

# %%
clf.feature_importances_
# Out:
# array([0.01935831, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.4466537 , 0.        , 0.        , 0.23640256,
#        0.01404795, 0.        , 0.28353749])

# %%
list(zip(feature_name, clf.feature_importances_))
# Out:
# [('酒精', 0.019358306363689518),
#  ('苹果酸', 0.0),
#  ('灰', 0.0),
#  ('灰的碱性', 0.0),
#  ('镁', 0.0),
#  ('总酚', 0.0),
#  ('类黄酮', 0.4466537022334635),
#  ('非黄烷类酚类', 0.0),
#  ('花青素', 0.0),
#  ('颜色强度', 0.23640255670418434),
#  ('色调', 0.014047945714076419),
#  ('od280/od315稀释葡萄酒', 0.0),
#  ('脯氨酸', 0.28353748898458625)]
